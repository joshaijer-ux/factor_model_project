# %%
from pathlib import Path

base = Path.cwd()

data_dir = base / "DATA"
raw_dir = data_dir / "raw"
processed_dir = data_dir / "processed"

raw_dir.mkdir(parents=True, exist_ok=True)
processed_dir.mkdir(parents=True, exist_ok=True)

print("Project folder:", base)
print("Raw data folder:", raw_dir)
print("Processed data folder:", processed_dir)
# Out:
# Project folder: /Users/joshaijer/Documents/factor_model_project
# Raw data folder: /Users/joshaijer/Documents/factor_model_project/DATA/raw
# Processed data folder: /Users/joshaijer/Documents/factor_model_project/DATA/processed

# %%
from pathlib import Path

base = Path.cwd()
data_dir = base / "DATA"
raw_dir = data_dir / "raw"
processed_dir = data_dir / "processed"

raw_dir.mkdir(parents=True, exist_ok=True)
processed_dir.mkdir(parents=True, exist_ok=True)

print("Base:", base)
print("Raw:", raw_dir)
print("Processed:", processed_dir)
# Out:
# Base: /Users/joshaijer/Documents/factor_model_project
# Raw: /Users/joshaijer/Documents/factor_model_project/DATA/raw
# Processed: /Users/joshaijer/Documents/factor_model_project/DATA/processed
